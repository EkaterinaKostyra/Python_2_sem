# %%
import pandas as pd
import json
with open('tinkoff_hh.json', encoding='utf8') as ti:
    file = ti.readlines()
a1 = [json.loads(x) for x in file if 'index' not in x]
a2 = pd.DataFrame(a1)

# %%
wage = a2[["vacancy","income","region"]][a2["income"] != "не указан"].drop_duplicates().sort_values(by = 'income')
wage
# Out:
#                                                 vacancy  \
# 1740                        Координатор в тренинг-центр
# 1371      Младший специалист кадрового делопроизводства
# 1528                             Тренер группы обучения
# 1551                             Тренер группы обучения
# 1553                             Тренер группы обучения
# 1508                             Тренер группы обучения
# 1574                             Тренер группы обучения
# 1526                             Тренер группы обучения
# 1082  Специалист Службы финансового мониторинга (Мет...
# 1714  Старший специалист по расследованиям (Фрод-мон...
# 2165  Руководитель группы сектора развития агентской...
# 2271  Руководитель группы сектора развития агентской...
# 2004         Агент по работе с корпоративными клиентами
# 1953         Агент по работе с корпоративными клиентами
# 256       Менеджер по работе с корпоративными клиентами
# 255       Менеджер по работе с корпоративными клиентами
# ...

# %%
wage["vacancy"].value_counts()
# Out:
# Агент по доставке продуктов Тинькофф                                              156
# Представитель Тинькофф                                                            109
# Консультант по работе с клиентами                                                  48
# Представитель Тинькофф Банка                                                       47
# Специалист по развитию агентской сети                                              41
# Менеджер по доставке продуктов банка                                               39
# Региональный консультант в Тинькофф                                                39
# Менеджер по привлечению юридических лиц                                            27
# Территориальный руководитель по привлечению юридических лиц                        25
# Региональный агент по работе с клиентами                                           24
# Специалист сектора сохранения клиентов                                             24
# ...

# %%
# !pip install pymorphy2
# !pip install pymorphy2-dicts
# !pip install DAWG-Python
# Out:
# WARNING: pip is being invoked by an old script wrapper. This will fail in a future version of pip.
# Please see https://github.com/pypa/pip/issues/5599 for advice on fixing the underlying issue.
# To avoid this problem you can invoke Python with '-m pip' instead of running pip directly.
# ...
# WARNING: pip is being invoked by an old script wrapper. This will fail in a future version of pip.
# Please see https://github.com/pypa/pip/issues/5599 for advice on fixing the underlying issue.
# To avoid this problem you can invoke Python with '-m pip' instead of running pip directly.
# ...
# WARNING: pip is being invoked by an old script wrapper. This will fail in a future version of pip.
# Please see https://github.com/pypa/pip/issues/5599 for advice on fixing the underlying issue.
# To avoid this problem you can invoke Python with '-m pip' instead of running pip directly.
# ...

# %%
import pandas as pd
import pymorphy2
import ssl
ssl._create_default_https_context = ssl._create_unverified_context
url = "https://raw.githubusercontent.com/dm-fedorov/pandas_basic/master/data/data_stat/yandex-stat-q.csv"
a1 = pymorphy2.MorphAnalyzer()
a2 = pd.read_csv(url)
print("Провести анализ частоты запросов к сайту по версии Яндекс.Метрики:\n")
a2.head()
# Out:
# Провести анализ частоты запросов к сайту по версии Яндекс.Метрики:
#                             Поисковая фраза Поисковая система  Визиты  \
# 0                           Итого и средние               NaN   72394
# 1                                 pycode.ru            Яндекс    2068
# 2                холопов алексей васильевич            Яндекс    1240
# 3                 золотое правило дидактики            Яндекс     778
# 4  золотое правило дидактики я.а коменского            Яндекс     743
#
#    Посетители    Отказы  Глубина просмотра Время на сайте
# 0       57803  0.120328           1.298934       00:01:18
# 1        1225  0.093810           1.674565       00:01:38
# 2         467  0.082258           1.941129       00:03:53
# 3         751  0.082262           1.087404       00:00:41
# 4         724  0.068641           1.044415       00:00:31

# %%
from matplotlib import pyplot as plt
# %matplotlib inline
a = [j for i, j in enumerate(a2["Поисковая фраза"].str.lower())]
lst = list(map(lambda x: x.split(), a))
b = [a1.parse(x)[0].normal_form for sl in lst for x in sl]
itog= pd.Series(b)
print("Определите статистику встречаемости отдельных слов в поисковых фразах:\n",itog.value_counts()[itog.value_counts()>1000])
# Out:
# Определите статистику встречаемости отдельных слов в поисковых фразах:
#  тезис             6848
# в                 6048
# на                4974
# конференция       4726
# по                4234
# научный           3992
# как               3746
# работа            3345
# для               3093
# и                 3080
# информационный    3040
# пример            2991
# безопасность      2721
# к                 2518
# правило           1906
# практика          1829
# что               1730
# доклад            1586
# статья            1463
# о                 1461
# золотой           1442
# отчёт             1344
# дидактика         1148
# кейс              1125
# какой             1080
# студент           1047
# с                 1030
# выступление       1005
# dtype: int64
