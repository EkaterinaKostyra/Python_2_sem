# %%
#Задание1
from datetime import datetime, timedelta
date_string = 'May 9 2017 9:00AM'
date_datetime = datetime.strptime(date_string, '%b %d %Y %H:%M%p')
hour = int(date_datetime.hour)
print(date_datetime)
print(hour)
# Out:
# 2017-05-09 09:00:00
# 9

# %%
#Задание2
date_string = 'May 9 2017 9:00AM'
date_datetime = datetime.strptime(date_string, '%b %d %Y %H:%M%p')
date_datetime += timedelta(hours=1)
print(date_datetime)
# Out:
# 2017-05-09 10:00:00

# %%
#Задание3
date_str = date_datetime.strftime('%Y-%m-%d')
print(date_str)
# Out:
# 2017-05-09

# %%
#Задание4
start_Date = '2017-01-01'
end_Date = '2017-01-03'
start_Date_datetime = datetime.strptime(startDate, '%Y-%m-%d')
end_Date_datetime = datetime.strptime(endDate, '%Y-%m-%d')
c_day = start_Date_datetime
c_day = start_Date_datetime
while c_day <= endDate_datetime:
    print(c_day.strftime('%Y-%m-%d %H:%M:%S'))
    c_day += timedelta(hours=1)
# Out:
# 2017-01-01 00:00:00
# 2017-01-01 01:00:00
# 2017-01-01 02:00:00
# 2017-01-01 03:00:00
# 2017-01-01 04:00:00
# 2017-01-01 05:00:00
# 2017-01-01 06:00:00
# 2017-01-01 07:00:00
# 2017-01-01 08:00:00
# 2017-01-01 09:00:00
# 2017-01-01 10:00:00
# 2017-01-01 11:00:00
# 2017-01-01 12:00:00
# 2017-01-01 13:00:00
# 2017-01-01 14:00:00
# 2017-01-01 15:00:00
# 2017-01-01 16:00:00
# 2017-01-01 17:00:00
# 2017-01-01 18:00:00
# 2017-01-01 19:00:00
# 2017-01-01 20:00:00
# 2017-01-01 21:00:00
# 2017-01-01 22:00:00
# 2017-01-01 23:00:00
# 2017-01-02 00:00:00
# 2017-01-02 01:00:00
# 2017-01-02 02:00:00
# 2017-01-02 03:00:00
# 2017-01-02 04:00:00
# 2017-01-02 05:00:00
# 2017-01-02 06:00:00
# 2017-01-02 07:00:00
# 2017-01-02 08:00:00
# 2017-01-02 09:00:00
# 2017-01-02 10:00:00
# 2017-01-02 11:00:00
# 2017-01-02 12:00:00
# 2017-01-02 13:00:00
# 2017-01-02 14:00:00
# 2017-01-02 15:00:00
# 2017-01-02 16:00:00
# 2017-01-02 17:00:00
# 2017-01-02 18:00:00
# 2017-01-02 19:00:00
# 2017-01-02 20:00:00
# 2017-01-02 21:00:00
# 2017-01-02 22:00:00
# 2017-01-02 23:00:00
# 2017-01-03 00:00:00
